# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_excel('/Users/nandini/Downloads/SalesData (2).xlsx')

# %%
df.head()
# Out:
#    Advertising  Temperature  Gender Region   Sales
# 0        57.45        25.82  Female   West  433.23
# 1        47.93        38.39    Male  South  386.91
# 2        59.72        24.37    Male   West  518.70
# 3        72.85        18.73    Male   West  466.22
# 4        46.49        17.55  Female  North  345.77

# %%
df = pd.get_dummies(df,columns=['Gender','Region'],drop_first=True).astype(int)

# %%
x.head()
# Out:
#    Advertising  Temperature  Gender_Male  Region_North  Region_South  \
# 0           57           25            0             0             0
# 1           47           38            1             0             1
# 2           59           24            1             0             0
# 3           72           18            1             0             0
# 4           46           17            0             1             0
#
#    Region_West
# 0            1
# 1            0
# 2            1
# 3            1
# 4            0

# %%
x = df.drop('Sales', axis=1)
y = df['Sales']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
x_train.head()
# Out:
#      Advertising  Temperature  Gender_Male  Region_North  Region_South  \
# 346           28           35            0             1             0
# 91            64           31            1             0             1
# 299           59           34            1             0             0
# 129           42           27            0             0             0
# 695           45           31            0             0             1
#
#      Region_West
# 346            0
# 91             0
# 299            1
# 129            0
# 695            0

# %%
x_train = sm.add_constant(x_train,prepend=False)

# %%
x_train.head()
# Out:
#      Advertising  Temperature  Gender_Male  Region_North  Region_South  \
# 346           28           35            0             1             0
# 91            64           31            1             0             1
# 299           59           34            1             0             0
# 129           42           27            0             0             0
# 695           45           31            0             0             1
#
#      Region_West  const
# 346            0    1.0
# 91             0    1.0
# 299            1    1.0
# 129            0    1.0
# 695            0    1.0

# %%
mod1 = sm.OLS(y_train, x_train).fit()

# %%
print(mod1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     373.0
# Date:                Tue, 23 Jun 2026   Prob (F-statistic):          1.01e-190
# Time:                        20:47:56   Log-Likelihood:                -2789.6
# No. Observations:                 560   AIC:                             5593.
# Df Residuals:                     553   BIC:                             5624.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Advertising      4.6753      0.101     46.257      0.000       4.477       4.874
# ...

# %%
# H0 = Advertising does not influence sales
# checking p values if p value less than level of significance
# we reject the null hypothesis
# it means advertising does influence the sales
# for every unit increase in advertising the the sales will increase by 4.6753

# %%
# H0 = temperature does not influence sales
# checking p values if p value more than level of significance
# we do not reject the null hypothesis
# it means temperature does not influence the sales

# %%
# h0= with respect to female if a male is selected that it does not influence the sales
# checking p value if p value less than level of significance
# we reject the null hypothesis
# it means with respect to female if a male is selcted that it does influence the sales
# with respect to female if you choose male then it will driectly increase the coef of sales by 12.8748

# %%
# h0= with respect to east if region north is selected that it does not influence the sales
# checking p value if p value less than level of significance
# we reject the null hypothesis
# it means with respect to east if a region north is selcted that it does influence the sales
# with respect to east if you choose north then it will driectly decrease the coef of sales by -18.6376

# %%
# h0= with respect to east if a region south is selected that it does not influence the sales
# checking p value if p value more than level of significance
# we do not reject the null hypothesis
# it means with respect to east if a south is selcted that it does not influence the sales
# with respect to east if you choose south region then it will driectly decrease the coef of sales by -4.6478

# %%
# h0= with respect to east if region west is selected that it does not influence the sales
# checking p value if p value less than level of significance
# we reject the null hypothesis
# it means with respect to east if a region west is selcted that it does influence the sales
# with respect to east if you choose west then it will driectly increase the coef of sales by 23.4241
